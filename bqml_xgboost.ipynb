# %%
# !pip install --upgrade google-cloud-bigquery[bqstorage,pandas]

# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %% [markdown]
# ### Let's look at the training data

# %%
# %%bigquery retail_dataset
#
# SELECT
#   EXTRACT (dayofweek
#   FROM
#     date) AS dayofweek,
#   EXTRACT (hour
#   FROM
#     date) AS hour,
#   EXTRACT (day
#   FROM
#     date) AS day,
#   EXTRACT (month
#   FROM
#     date) AS month,
#   deviceCategory,
#   isMobile,
#   operatingSystem,
#   browser,
#   country,
#   city,
#   trafficSource,
#   trafficMedium,
#   trafficCampaign,
#   isFirstVisit,
#   totalPageviews,
#   totalTimeOnSite,
#   productPagesViewed,
#   addedToCart
# FROM
#   `kaggleworkshops.google_analytics_sample.train`

# %%
retail_dataset
# Out:
#         dayofweek  hour  day  month deviceCategory  isMobile operatingSystem  \
# 0               1     0    2      4         tablet      True             iOS
# 1               1     0    2      4         mobile      True             iOS
# 2               1     0    2      4         tablet      True             iOS
# 3               1     0    2      4         tablet      True             iOS
# 4               1     0    2      4         tablet      True             iOS
# ...           ...   ...  ...    ...            ...       ...             ...
# 765702          3     0   16      5        desktop     False       Macintosh
# 765703          3     0   16      5        desktop     False       Macintosh
# 765704          3     0   16      5        desktop     False       Macintosh
# 765705          3     0   16      5        desktop     False       Macintosh
# 765706          3     0   16      5        desktop     False       Macintosh
#
#        browser        country                           city trafficSource  \
# 0       Safari  United States  not available in demo dataset      (direct)
# 1       Safari  United States                  San Francisco      (direct)
# 2       Safari  United States  not available in demo dataset      (direct)
# 3       Safari      Australia  not available in demo dataset      (direct)
# 4       Safari  United States  not available in demo dataset      (direct)
# ...        ...            ...                            ...           ...
# 765702  Chrome  United States                  San Francisco        google
# 765703  Chrome  United States  not available in demo dataset        google
# 765704  Chrome  United States  not available in demo dataset      (direct)
# 765705  Chrome  United States                  Mountain View      (direct)
# 765706  Chrome  United States                        Seattle      (direct)
#
#        trafficMedium trafficCampaign  isFirstVisit  totalPageviews  \
# 0             (none)       (not set)             0              35
# 1             (none)       (not set)             1              52
# 2             (none)       (not set)             1             110
# 3             (none)       (not set)             1               9
# 4             (none)       (not set)             0              25
# ...              ...             ...           ...             ...
# 765702       organic       (not set)             1              15
# 765703       organic       (not set)             1              16
# 765704        (none)       (not set)             1              16
# 765705        (none)       (not set)             0              16
# 765706        (none)       (not set)             0              16
#
#         totalTimeOnSite  productPagesViewed  addedToCart
# 0                   250                  12            1
# 1                  3171                   6            1
# 2                  2443                  20            1
# 3                   198                   4            1
# 4                  1024                   1            1
# ...                 ...                 ...          ...
# 765702              472                   1            0
# 765703              379                   0            1
# 765704              353                   0            1
# 765705              377                   1            0
# 765706              733                   0            0
#
# [765707 rows x 18 columns]

# %% [markdown]
# ### Train an xgboost model

# %%
# %%bigquery
#
# CREATE OR REPLACE MODEL
#   bqmlretail.boosted_tree_model OPTIONS( model_type='boosted_tree_classifier',
#     INPUT_LABEL_COLS=["addedToCart"]) AS
# SELECT
#   EXTRACT (dayofweek
#   FROM
#     date) AS dayofweek,
#   EXTRACT (hour
#   FROM
#     date) AS hour,
#   EXTRACT (day
#   FROM
#     date) AS day,
#   EXTRACT (month
#   FROM
#     date) AS month,
#   deviceCategory,
#   isMobile,
#   operatingSystem,
#   browser,
#   country,
#   city,
#   trafficSource,
#   trafficMedium,
#   trafficCampaign,
#   isFirstVisit,
#   totalPageviews,
#   totalTimeOnSite,
#   productPagesViewed,
#   addedToCart
# FROM
#   `kaggleworkshops.google_analytics_sample.train`;
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Get training info

# %%
# %%bigquery
# SELECT
#   *
# FROM
#   ML.TRAINING_INFO(MODEL bqmlretail.boosted_tree_model)
# Out:
#     training_run  iteration      loss  eval_loss  learning_rate  duration_ms
# 0              0         20  0.092215   0.091216            0.3           81
# 1              0         19  0.092580   0.091480            0.3           41
# 2              0         18  0.093071   0.091898            0.3           57
# 3              0         17  0.093693   0.092412            0.3           82
# 4              0         16  0.094472   0.093189            0.3           41
# 5              0         15  0.095502   0.094243            0.3           62
# 6              0         14  0.096872   0.095483            0.3           63
# 7              0         13  0.098773   0.097251            0.3        14054
# 8              0         12  0.101249   0.099675            0.3           59
# 9              0         11  0.104630   0.103096            0.3           73
# 10             0         10  0.109302   0.107743            0.3           77
# 11             0          9  0.115803   0.114252            0.3           73
# 12             0          8  0.124729   0.123130            0.3           77
# 13             0          7  0.137215   0.135846            0.3           63
# 14             0          6  0.154702   0.153240            0.3           71
# 15             0          5  0.179283   0.177824            0.3           47
# 16             0          4  0.214618   0.213210            0.3        13927
# 17             0          3  0.266064   0.264745            0.3           55
# 18             0          2  0.343604   0.342603            0.3           70
# 19             0          1  0.467740   0.466999            0.3       416414

# %% [markdown]
# ### Evaluate Model

# %%
BUCKET = 'gs://<bucket-name>/exported/xgboost'

# %%
# %%bigquery
# SELECT
#   *
# FROM
#   ML.EVALUATE (MODEL bqmlretail.boosted_tree_model)
# Out:
#    precision    recall  accuracy  f1_score  log_loss  roc_auc
# 0   0.690184  0.419776  0.958346  0.522042  0.091242  0.97138

# %% [markdown]
# ### Export Model to GCS

# %%
# !bq extract --destination_format ML_XGBOOST_BOOSTER -m bqmlretail.boosted_tree_model $BUCKET
# Out:
# FATAL Flags parsing error: flag --destination_format=XGBOOST_BOOSTER: value should be one of <CSV|NEWLINE_DELIMITED_JSON|AVRO|SAVED_MODEL>
# Run 'bq.py help' to get help

# %%
# !gsutil ls $BUCKET
# Out:
# gs://camus-bqml-retail/exported/xgboost/main.py
# gs://camus-bqml-retail/exported/xgboost/model.bst
# gs://camus-bqml-retail/exported/xgboost/xgboost_predictor-0.1.tar.gz
# gs://camus-bqml-retail/exported/xgboost/assets/

# %% [markdown]
# ### Copy model locally

# %%
# !gsutil cp -r $BUCKET .
# Out:
# Copying gs://camus-bqml-retail/exported/xgboost/assets/10.txt...
# Copying gs://camus-bqml-retail/exported/xgboost/assets/11.txt...
# Copying gs://camus-bqml-retail/exported/xgboost/assets/12.txt...
# Copying gs://camus-bqml-retail/exported/xgboost/assets/4.txt...
# - [4 files][  4.2 KiB/  4.2 KiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://camus-bqml-retail/exported/xgboost/assets/5.txt...
# Copying gs://camus-bqml-retail/exported/xgboost/assets/6.txt...
# Copying gs://camus-bqml-retail/exported/xgboost/assets/7.txt...
# Copying gs://camus-bqml-retail/exported/xgboost/assets/8.txt...
# Copying gs://camus-bqml-retail/exported/xgboost/assets/9.txt...
# Copying gs://camus-bqml-retail/exported/xgboost/assets/model_metadata.json...
# Copying gs://camus-bqml-retail/exported/xgboost/main.py...
# Copying gs://camus-bqml-retail/exported/xgboost/model.bst...
# Copying gs://camus-bqml-retail/exported/xgboost/xgboost_predictor-0.1.tar.gz...
# / [13 files][195.6 KiB/195.6 KiB]
# Operation completed over 13 objects/195.6 KiB.

# %% [markdown]
# ### Unzip model

# %%
# %pushd xgboost
# !tar -xf xgboost_predictor-0.1.tar.gz
# Out:
# /home/jupyter/BQ demo/xgboost
# /home/jupyter/BQ demo
# popd -> ~/BQ demo

# %% [markdown]
# ### Make a prediction

# %%
# !python main.py '[{"dayofweek": 1,"hour": 0, "day": 28, "month": 8, "deviceCategory": "tablet", "isMobile": true, "operatingSystem": "iOS", "browser": "Safari", "country": "United States", "city": "San Jose", "trafficSource": "google", "trafficMedium": "organic", "trafficCampaign": "(not set)", "isFirstVisit": 1, "totalPageviews": 23, "totalTimeOnSite": 478, "productPagesViewed": 9 }]'
# Out:
# /home/jupyter/BQ demo/xgboost
# [09:59:11] WARNING: /workspace/src/learner.cc:727: Loading model from XGBoost < 1.0.0, consider saving it again for improved compatibility
# [{'predicted_addedToCart': '0', 'addedToCart_values': ['1', '0'], 'addedToCart_probs': [0.39972978830337524, 0.6002702116966248]}]
